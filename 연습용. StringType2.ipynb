# %%
import os.path
from sys import hash_info

number = 3
"I eat %d apples" % number
# Out:
# 'I eat 3 apples'

# %%
"I eat {0} apples" .format("five")
# Out:
# 'I eat five apples'

# %%
"I ate {number} apples. so I was sick for {day} days." .format(number = 10, day=3)
# Out:
# 'I ate 10 apples. so I was sick for 3 days.'

# %%
"{0:=>10}".format("hi")
# Out:
# '========hi'

# %%
y = 3.42134234
"stay force {0} {1:0.4f}".format("1",y)
# Out:
# 'stay force 1 3.4213'

# %%
name = '홍길동'
age = 30
f'나의 이름은 {name}입니다. 나의 나이는 {age}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나의 나이는 30입니다.'

# %%
ssn = "881213-1234567"
fullyear = "20" + ssn[0:2]
print(f"귀하의 출생년도는 {fullyear}년 입니다.")

if int(fullyear) >= 2000 :
    print(f"귀하의 출생년도는 2000년도 이상입니다.")
else:
    print(f"귀하의 출생년도는 2000년도 미만입니다.")
# Out:
# 귀하의 출생년도는 2088년 입니다.
# 귀하의 출생년도는 2000년도 이상입니다.

# %%
a = 'hi'
a.upper()
# Out:
# 'HI'

# %%
a
# Out:
# 'hi'

# %%
a = a.upper()
a
# Out:
# 'HI'
