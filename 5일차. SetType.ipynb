# %%
#집합 자료형(set)
#로또 주머니와 같이 중복을 허용하지 않고 순서가 없는
#데이터들의 모임이다.
#교집합, 합집합, 차집합 등의 집합 연산을 쉽게 처리할 수 있다.

s1 = set([1,2,3]) #set()에 값을 넣으면 된다.
print(s1)
# Out:
# {1, 2, 3}

# %%
s2 = set("hello")
print(s2)
# Out:
# {'h', 'o', 'e', 'l'}

# %%
type(s2)
# Out:
# set

# %%
s3 = {"a","b","c"}
print(s3)
# Out:
# {'c', 'b', 'a'}
